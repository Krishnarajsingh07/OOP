# %%
3/4*1/2
# Out:
# 0.375

# %%
class Fraction:
    
    
    # Parameterized constructor
    def __init__(self,x,y):
        self.num = x
        self.den = y

# %%
fr1 = Fraction(3,4)

# %%
print(type(fr1))
# Out:
# <class '__main__.Fraction'>

# %%
print(fr1)
# Out:
# <__main__.Fraction object at 0x000001981A1DBE00>

# %%
class Fraction:
    
    
    # Parameterized constructor
    def __init__(self,x,y):
        self.num = x
        self.den = y
        
        
    # ye second magic method h 
    # ye hamseha string return krta hai
    def __str__(self):
        return '{}/{}'.format(self.num,self.den)
    
    # 3rd magic method
    # ye addition ke liye use hota hai
    def __add__(self, other):
        # self is fr2 and other is fr3
        new_num = self.num*other.den + other.num * self.den
        new_den = self.den * other.den
        
        return '{}/{}'.format(new_num,new_den)
    
    def __sub__(self, other):
        
        # self is fr2 and other is fr3
        new_num = self.num*other.den - other.num * self.den
        new_den = self.den * other.den
        
        return '{}/{}'.format(new_num,new_den)
        
    def __mul__(self, other):
        new_num = self.num*other.num
        new_den = self.den * other.den
        
        return '{}/{}'.format(new_num,new_den)
    
    def __truediv__(self, other):
        
        new_num = self.num*other.den
        new_den = self.den * other.num
        
        return '{}/{}'.format(new_num,new_den)
        
        
        
    # Non magic method
    
    def Change_to_decimal(self):
        return self.num/self.den

# %%
fr2 = Fraction(34,6)

# %%
fr3 = Fraction(23,45)

# %%
print(fr2)
print(fr3)
# Out:
# 34/6
# 23/45

# %%
print(fr2 + fr3)
print(fr2-fr3)
print(fr2*fr3)
print(fr2/fr3)
# Out:
# 1668/270
# 1392/270
# 782/270
# 1530/138

# %%
fr3.Change_to_decimal()
# Out:
# 0.5111111111111111
